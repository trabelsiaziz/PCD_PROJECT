# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import mediapipe as mp
import time
import os

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities
mp_face_mesh = mp.solutions.face_mesh

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    return image, results

# %%
def draw_landmarks(image, results):
    # Face (light gray thin mesh)
    mp_drawing.draw_landmarks(
        image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
        None, mp_drawing.DrawingSpec((200,200,200), thickness=1))
    
    # Pose (blue thick lines with green dots)
    mp_drawing.draw_landmarks(
        image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
        mp_drawing.DrawingSpec((0,255,0), circle_radius=2),
        mp_drawing.DrawingSpec((255,0,0), thickness=3))
    
    # Hands (orange left/magenta right)
    mp_drawing.draw_landmarks(
        image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
        None, mp_drawing.DrawingSpec((0,165,255), thickness=2))
    
    mp_drawing.draw_landmarks(
        image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
        None, mp_drawing.DrawingSpec((255,0,255), thickness=2))

# %%
def extract_keypoints(results) : 
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(63)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(63)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

    return np.concatenate([face, pose, lh, rh])

# %%
video_name = 'movie.mp4'
video_path = os.path.join('DATA_COLLECTION', 'movie', video_name);

# %%
cap = cv2.VideoCapture(video_path)


with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened() : 
        ret, frame = cap.read()
        if not ret : 
            break
    
        image, results = mediapipe_detection(frame, holistic)

        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        print(pose.shape)

        draw_landmarks(image, results)
        cv2.imshow('modified_frames', image)

        if cv2.waitKey(50) & 0xFF == ord('q'):
            break


cap.release()
cv2.destroyAllWindows()
# Out:
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)

# %% [raw]
# cap.release()
# cv2.destroyAllWindows()

# %%
res = np.array(results)
if res is None:
    print("Frame is empty or not loaded correctly.")
else:
    print("Shape:", res.shape)
# Out:
# Shape: ()

# %% [raw]
# pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
# pose

# %%
import os
import json

# Load the JSON data from the file
with open('WLASL_v0.3.json', 'r') as f:
    data = json.load(f)

root = 'DATA_COLLECTION_version_3'

def time(start):
    secs = (start + 29) // 30
    mint = secs // 60
    secs = secs % 60
    return f"{mint} : {secs}"

for item in data:
    gloss = item['gloss']
    instances = item['instances']

    for video in instances:
        video_id = video['video_id']
        path = os.path.join(root, video_id)
        start_frame = video['frame_start']
        end_frame = video['frame_end']
        dif = end_frame - start_frame
        save_path = os.path.join(root, gloss, f"{video_id}.mp4")

        if os.path.exists(save_path):
            print('here')
            if dif > 30:
                print(f"The video in: {gloss} {path} has difference: {dif}, starts at: {time(start_frame)}")
# Out:
# here
# here
# here
# here
# The video in: book DATA_COLLECTION_version_3\70212 has difference: 99, starts at: 1 : 12
# here
# The video in: book DATA_COLLECTION_version_3\70266 has difference: 120, starts at: 2 : 5
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: drink DATA_COLLECTION_version_3\70173 has difference: 121, starts at: 3 : 11
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: computer DATA_COLLECTION_version_3\12306 has difference: 59, starts at: 2 : 51
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: before DATA_COLLECTION_version_3\05724 has difference: 46, starts at: 0 : 58
# here
# The video in: before DATA_COLLECTION_version_3\70348 has difference: 95, starts at: 2 : 40
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: chair DATA_COLLECTION_version_3\70230 has difference: 130, starts at: 1 : 11
# here
# The video in: chair DATA_COLLECTION_version_3\70263 has difference: 117, starts at: 1 : 44
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: go DATA_COLLECTION_version_3\24857 has difference: 39, starts at: 0 : 30
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: clothes DATA_COLLECTION_version_3\11305 has difference: 59, starts at: 2 : 12
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: who DATA_COLLECTION_version_3\63219 has difference: 76, starts at: 1 : 12
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: candy DATA_COLLECTION_version_3\08909 has difference: 52, starts at: 0 : 25
# here
# here
# The video in: candy DATA_COLLECTION_version_3\70326 has difference: 125, starts at: 2 : 57
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cousin DATA_COLLECTION_version_3\70332 has difference: 101, starts at: 0 : 39
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: deaf DATA_COLLECTION_version_3\14855 has difference: 46, starts at: 0 : 17
# here
# The video in: deaf DATA_COLLECTION_version_3\70015 has difference: 91, starts at: 2 : 28
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: fine DATA_COLLECTION_version_3\70234 has difference: 108, starts at: 2 : 35
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: help DATA_COLLECTION_version_3\27194 has difference: 46, starts at: 0 : 47
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: no DATA_COLLECTION_version_3\38482 has difference: 79, starts at: 0 : 44
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: thin DATA_COLLECTION_version_3\57919 has difference: 49, starts at: 1 : 12
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: walk DATA_COLLECTION_version_3\62152 has difference: 62, starts at: 0 : 7
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: year DATA_COLLECTION_version_3\64201 has difference: 76, starts at: 0 : 1
# here
# here
# here
# The video in: year DATA_COLLECTION_version_3\70306 has difference: 129, starts at: 0 : 29
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: yes DATA_COLLECTION_version_3\64275 has difference: 69, starts at: 0 : 4
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: all DATA_COLLECTION_version_3\01912 has difference: 49, starts at: 0 : 56
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: black DATA_COLLECTION_version_3\06455 has difference: 49, starts at: 1 : 44
# here
# here
# The video in: black DATA_COLLECTION_version_3\70244 has difference: 95, starts at: 0 : 39
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cool DATA_COLLECTION_version_3\70271 has difference: 147, starts at: 2 : 45
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: finish DATA_COLLECTION_version_3\21933 has difference: 52, starts at: 0 : 48
# here
# The video in: finish DATA_COLLECTION_version_3\70361 has difference: 117, starts at: 4 : 16
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: hot DATA_COLLECTION_version_3\28074 has difference: 36, starts at: 1 : 15
# here
# here
# The video in: hot DATA_COLLECTION_version_3\70270 has difference: 99, starts at: 2 : 30
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: like DATA_COLLECTION_version_3\70299 has difference: 121, starts at: 3 : 5
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: many DATA_COLLECTION_version_3\34822 has difference: 56, starts at: 0 : 16
# here
# here
# The video in: many DATA_COLLECTION_version_3\70308 has difference: 114, starts at: 0 : 51
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: want DATA_COLLECTION_version_3\62241 has difference: 49, starts at: 0 : 10
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: work DATA_COLLECTION_version_3\63769 has difference: 49, starts at: 1 : 58
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: africa DATA_COLLECTION_version_3\01382 has difference: 43, starts at: 0 : 34
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: basketball DATA_COLLECTION_version_3\05227 has difference: 52, starts at: 0 : 35
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: birthday DATA_COLLECTION_version_3\06355 has difference: 46, starts at: 1 : 39
# here
# The video in: birthday DATA_COLLECTION_version_3\70357 has difference: 135, starts at: 3 : 50
# here
# The video in: birthday DATA_COLLECTION_version_3\70359 has difference: 99, starts at: 4 : 1
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: brown DATA_COLLECTION_version_3\07957 has difference: 46, starts at: 2 : 45
# here
# here
# The video in: brown DATA_COLLECTION_version_3\70242 has difference: 95, starts at: 0 : 29
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: but DATA_COLLECTION_version_3\08421 has difference: 39, starts at: 2 : 54
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cheat DATA_COLLECTION_version_3\10146 has difference: 52, starts at: 1 : 18
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: city DATA_COLLECTION_version_3\10888 has difference: 49, starts at: 1 : 57
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cook DATA_COLLECTION_version_3\13154 has difference: 52, starts at: 3 : 18
# here
# The video in: cook DATA_COLLECTION_version_3\70030 has difference: 91, starts at: 1 : 58
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: decide DATA_COLLECTION_version_3\15031 has difference: 59, starts at: 0 : 23
# here
# The video in: decide DATA_COLLECTION_version_3\70119 has difference: 105, starts at: 2 : 16
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: full DATA_COLLECTION_version_3\70029 has difference: 111, starts at: 1 : 53
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: how DATA_COLLECTION_version_3\28187 has difference: 36, starts at: 1 : 20
# here
# here
# The video in: how DATA_COLLECTION_version_3\70295 has difference: 93, starts at: 2 : 21
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: jacket DATA_COLLECTION_version_3\30830 has difference: 39, starts at: 0 : 2
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: letter DATA_COLLECTION_version_3\70325 has difference: 104, starts at: 2 : 52
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: need DATA_COLLECTION_version_3\37879 has difference: 39, starts at: 0 : 17
# here
# The video in: need DATA_COLLECTION_version_3\70237 has difference: 117, starts at: 3 : 5
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: paint DATA_COLLECTION_version_3\40816 has difference: 72, starts at: 0 : 4
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: paper DATA_COLLECTION_version_3\70211 has difference: 100, starts at: 1 : 7
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: pull DATA_COLLECTION_version_3\45252 has difference: 49, starts at: 3 : 44
# here
# here
# The video in: pull DATA_COLLECTION_version_3\70378 has difference: 111, starts at: 2 : 55
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: purple DATA_COLLECTION_version_3\45432 has difference: 39, starts at: 3 : 49
# here
# here
# here
# The video in: purple DATA_COLLECTION_version_3\70247 has difference: 100, starts at: 0 : 53
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: son DATA_COLLECTION_version_3\53258 has difference: 49, starts at: 3 : 42
# here
# The video in: son DATA_COLLECTION_version_3\70335 has difference: 120, starts at: 0 : 59
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: tell DATA_COLLECTION_version_3\57273 has difference: 36, starts at: 0 : 28
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: thursday DATA_COLLECTION_version_3\58359 has difference: 52, starts at: 1 : 29
# here
# The video in: thursday DATA_COLLECTION_version_3\70026 has difference: 91, starts at: 0 : 47
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: visit DATA_COLLECTION_version_3\61804 has difference: 56, starts at: 0 : 19
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: wait DATA_COLLECTION_version_3\62077 has difference: 62, starts at: 0 : 1
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: water DATA_COLLECTION_version_3\62479 has difference: 52, starts at: 0 : 24
# here
# here
# The video in: water DATA_COLLECTION_version_3\70069 has difference: 103, starts at: 1 : 38
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: wife DATA_COLLECTION_version_3\63325 has difference: 52, starts at: 1 : 19
# here
# The video in: wife DATA_COLLECTION_version_3\70333 has difference: 90, starts at: 0 : 50
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: yellow DATA_COLLECTION_version_3\70240 has difference: 105, starts at: 0 : 14
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: backpack DATA_COLLECTION_version_3\04614 has difference: 49, starts at: 0 : 9
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: brother DATA_COLLECTION_version_3\07929 has difference: 32, starts at: 2 : 44
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cat DATA_COLLECTION_version_3\09431 has difference: 56, starts at: 0 : 40
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: class DATA_COLLECTION_version_3\10965 has difference: 52, starts at: 1 : 58
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cry DATA_COLLECTION_version_3\14172 has difference: 56, starts at: 3 : 58
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: different DATA_COLLECTION_version_3\16190 has difference: 39, starts at: 1 : 27
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: door DATA_COLLECTION_version_3\17317 has difference: 76, starts at: 2 : 18
# here
# The video in: door DATA_COLLECTION_version_3\70264 has difference: 117, starts at: 1 : 49
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: green DATA_COLLECTION_version_3\25674 has difference: 42, starts at: 1 : 7
# here
# here
# The video in: green DATA_COLLECTION_version_3\70241 has difference: 101, starts at: 0 : 25
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: hair DATA_COLLECTION_version_3\26122 has difference: 76, starts at: 0 : 3
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: have DATA_COLLECTION_version_3\70221 has difference: 99, starts at: 2 : 7
# here
# here
# here
# here
# here
# here
# here
# The video in: headache DATA_COLLECTION_version_3\26832 has difference: 42, starts at: 0 : 30
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: knife DATA_COLLECTION_version_3\31841 has difference: 49, starts at: 0 : 18
# here
# The video in: knife DATA_COLLECTION_version_3\70320 has difference: 96, starts at: 2 : 22
# here
# here
# here
# here
# here
# here
# here
# The video in: laugh DATA_COLLECTION_version_3\32373 has difference: 59, starts at: 0 : 14
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: learn DATA_COLLECTION_version_3\32598 has difference: 56, starts at: 0 : 29
# here
# here
# The video in: learn DATA_COLLECTION_version_3\70205 has difference: 116, starts at: 0 : 16
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: movie DATA_COLLECTION_version_3\37120 has difference: 52, starts at: 1 : 21
# here
# here
# here
# here
# here
# here
# here
# The video in: rabbit DATA_COLLECTION_version_3\45835 has difference: 39, starts at: 0 : 1
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: read DATA_COLLECTION_version_3\46260 has difference: 69, starts at: 0 : 19
# here
# here
# The video in: read DATA_COLLECTION_version_3\70274 has difference: 114, starts at: 3 : 37
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: red DATA_COLLECTION_version_3\46712 has difference: 66, starts at: 0 : 37
# here
# here
# The video in: red DATA_COLLECTION_version_3\70239 has difference: 95, starts at: 0 : 10
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: room DATA_COLLECTION_version_3\48507 has difference: 62, starts at: 2 : 9
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: show DATA_COLLECTION_version_3\70231 has difference: 116, starts at: 1 : 32
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: sick DATA_COLLECTION_version_3\51494 has difference: 59, starts at: 2 : 10
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: snow DATA_COLLECTION_version_3\52834 has difference: 56, starts at: 3 : 17
# here
# here
# The video in: snow DATA_COLLECTION_version_3\70122 has difference: 103, starts at: 2 : 46
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: take DATA_COLLECTION_version_3\56652 has difference: 42, starts at: 0 : 3
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: tea DATA_COLLECTION_version_3\57034 has difference: 59, starts at: 0 : 14
# here
# here
# The video in: tea DATA_COLLECTION_version_3\70034 has difference: 103, starts at: 2 : 18
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: teacher DATA_COLLECTION_version_3\57037 has difference: 52, starts at: 0 : 18
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: week DATA_COLLECTION_version_3\62728 has difference: 36, starts at: 0 : 45
# here
# The video in: week DATA_COLLECTION_version_3\70304 has difference: 120, starts at: 0 : 19
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: why DATA_COLLECTION_version_3\63279 has difference: 72, starts at: 1 : 15
# here
# The video in: why DATA_COLLECTION_version_3\70213 has difference: 86, starts at: 1 : 22
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: with DATA_COLLECTION_version_3\63574 has difference: 66, starts at: 1 : 36
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: write DATA_COLLECTION_version_3\64049 has difference: 76, starts at: 2 : 17
# here
# here
# The video in: write DATA_COLLECTION_version_3\70261 has difference: 93, starts at: 1 : 30
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: yesterday DATA_COLLECTION_version_3\64303 has difference: 66, starts at: 0 : 6
# here
# The video in: yesterday DATA_COLLECTION_version_3\70347 has difference: 110, starts at: 2 : 24
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: again DATA_COLLECTION_version_3\01457 has difference: 39, starts at: 0 : 38
# here
# The video in: again DATA_COLLECTION_version_3\70219 has difference: 80, starts at: 1 : 59
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: bad DATA_COLLECTION_version_3\04694 has difference: 46, starts at: 0 : 12
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: ball DATA_COLLECTION_version_3\04833 has difference: 56, starts at: 0 : 20
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: bathroom DATA_COLLECTION_version_3\05296 has difference: 66, starts at: 0 : 39
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: blanket DATA_COLLECTION_version_3\06550 has difference: 66, starts at: 1 : 47
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: buy DATA_COLLECTION_version_3\08478 has difference: 36, starts at: 3 : 0
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: coffee DATA_COLLECTION_version_3\11552 has difference: 56, starts at: 2 : 20
# here
# The video in: coffee DATA_COLLECTION_version_3\70298 has difference: 102, starts at: 2 : 41
# here
# The video in: coffee DATA_COLLECTION_version_3\70033 has difference: 126, starts at: 2 : 12
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: college DATA_COLLECTION_version_3\11704 has difference: 46, starts at: 2 : 22
# here
# here
# The video in: college DATA_COLLECTION_version_3\70206 has difference: 116, starts at: 0 : 31
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: copy DATA_COLLECTION_version_3\13258 has difference: 46, starts at: 3 : 24
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: cute DATA_COLLECTION_version_3\14450 has difference: 39, starts at: 4 : 10
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: daughter DATA_COLLECTION_version_3\14748 has difference: 49, starts at: 0 : 10
# here
# The video in: daughter DATA_COLLECTION_version_3\70334 has difference: 95, starts at: 0 : 54
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: example DATA_COLLECTION_version_3\20064 has difference: 36, starts at: 1 : 38
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: far DATA_COLLECTION_version_3\21052 has difference: 39, starts at: 0 : 16
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: first DATA_COLLECTION_version_3\22071 has difference: 42, starts at: 0 : 50
# here
# The video in: first DATA_COLLECTION_version_3\70083 has difference: 123, starts at: 4 : 4
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: friend DATA_COLLECTION_version_3\23567 has difference: 59, starts at: 1 : 43
# here
# The video in: friend DATA_COLLECTION_version_3\70342 has difference: 99, starts at: 1 : 39
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: good DATA_COLLECTION_version_3\25037 has difference: 42, starts at: 0 : 40
# here
# here
# The video in: good DATA_COLLECTION_version_3\70259 has difference: 95, starts at: 2 : 56
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: happy DATA_COLLECTION_version_3\26506 has difference: 62, starts at: 0 : 16
# here
# The video in: happy DATA_COLLECTION_version_3\70284 has difference: 93, starts at: 0 : 47
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# The video in: home DATA_COLLECTION_version_3\27762 has difference: 39, starts at: 1 : 3
# here

# %%
video_path = os.path.join(root, 'go', f"{24857}.mp4")

cap = cv2.VideoCapture(video_path)


with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened() : 
        ret, frame = cap.read()
        if not ret : 
            break
    
        image, results = mediapipe_detection(frame, holistic)

        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten()
        print(pose.shape)

        draw_landmarks(image, results)
        cv2.imshow('modified_frames', image)

        if cv2.waitKey(50) & 0xFF == ord('q'):
            break


cap.release()
cv2.destroyAllWindows()
# Out:
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
# (132,)
